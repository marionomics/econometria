# %% [markdown]
# # Diferencias en Diferencias
#
# > Algebra's like sheet music: the important thing isn't can you read music. It's can you hear it.
# > Can you hear it?
# > Niels Bohr en Oppenheimer

# %%
2 + 2
# Out:
# 4
